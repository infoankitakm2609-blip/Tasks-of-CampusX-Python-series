# %% [markdown]
# <a href="https://colab.research.google.com/github/infoankitakm2609-blip/Tasks-of-CampusX-Python-series/blob/main/Quadratic-Equation-OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod=x
    self.y_cod=y

  def __str__(self):
    return "<{},{}>".format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod- other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    # return ((self.x_cod)**2 + (self.y_cod)**2)**0.5
    return self.euclidean_distance(Point(0,0))


class Line():

  def __init__(self,A,B,C):
    self.A=A
    self.B=B
    self.C=C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

  def point_on_line(line,point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "Point lies on the line."
    else:
      return "Point does not lie on the line."

  def shortest_distance(line,point):
    num=line.A*point.x_cod + line.B*point.y_cod + line.C
    den=((line.A)**2 + (line.B)**2)**0.5
    return num/den

# %%
p1=Point(0,0)
p2=Point(1,1)
p3=Point(3,3)
l1=Line(2,3,0)
print(l1)
# Out:
# 2x + 3y + 0 = 0

# %%
print(p1.euclidean_distance(p2))
print(l1.shortest_distance(p1))
# Out:
# 1.4142135623730951
# 0.0
