# %% [markdown]
# <a href="https://colab.research.google.com/github/infoankitakm2609-blip/Tasks-of-CampusX-Python-series/blob/main/Aggregation-inheritance-abstraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aggregation(Has-A relationship)

# %% [markdown]
# Example
# 1. Customer has an address.
# 2. Restaurant has a menu.

# %%
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address



  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)


  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name = new_name
    self.address.edit_address(new_city,new_pin,new_state)



class Address:

  def __init__(self,city,pin,state):
    self.__city = city
    self.pin = pin
    self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state


add = Address("Gorakhpur",273413,"Uttar pradesh")
cust = Customer("rohan","male",add)

cust.print_address()
cust.edit_profile("Ankit","lucknow",226201,"Uttar Pradesh")
cust.print_address()
# Out:
# Gorakhpur 273413 Uttar pradesh
# lucknow 226201 Uttar Pradesh

# %% [markdown]
# Inheritance and it's benefits

# %%
#Parent class
class User:
  def __init__(self):
    self.name = "ankit"

  def login(self):
    print("Login")

#Child class
class Student(User):

  def __init__(self):
    super().__init__()     #TO AVOID METHOD OVERRIDING
    self.rollno = 100

  def enroll(self):
    print("Enroll into the course")

  def login(self):
    print("Kya be kutareya!!")

u = User()
s = Student()

print(s.name)
print(s.rollno)

s.login()
s.enroll()
# Out:
# ankit
# 100
# Kya be kutareya!!
# Enroll into the course

# %% [markdown]
# Abstraction

# %%
from abc import ABC,abstractmethod
class BankApp(ABC):

  def database(self):
    print("Connected to database ")

  @abstractmethod
  def security(self):
    pass

  @abstractmethod
  def display(Self):
    pass

# %%
class MobileApp(BankApp):

  def mobile_login(self):
    print("Login into mobile")

  def security(self):
    print("mobile security")

  def display(Self):
    print("Displaying data")

# %%
mob = MobileApp()

# %%
mob.database()
# Out:
# Connected to database

# %%
mob.display()
# Out:
# Displaying data
